# %%
import pandas as pd
import tensorflow as tf


from tensorflow import keras

from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("gas_turbines.csv")

# %%
data.isna().sum()
# Out:
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# TEY     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
x = data.drop(labels="TEY",axis = 1)
y = data[["TEY"]]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20)

# %%
model = tf.keras.models.Sequential([ tf.keras.layers.Flatten(input_dim = 10),
                                    tf.keras.layers.Dense(9,activation = "relu"),
                                    tf.keras.layers.Dense(1,activation = "relu")
    
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 10)                0
#
#  dense_1 (Dense)             (None, 9)                 99
#
#  dense_2 (Dense)             (None, 1)                 10
#
# =================================================================
# Total params: 109
# Trainable params: 109
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import mean_absolute_error

# %%
model.compile(optimizer='adam',loss='mean_absolute_error')

# %%
model.fit(x_train,y_train,epochs=12)
# Out:
# Epoch 1/12
# 376/376 [==============================] - 1s 2ms/step - loss: 134.2404
# Epoch 2/12
# 376/376 [==============================] - 1s 2ms/step - loss: 134.2406
# Epoch 3/12
# 376/376 [==============================] - 1s 2ms/step - loss: 134.2405
# Epoch 4/12
# 376/376 [==============================] - 1s 2ms/step - loss: 134.2405
# Epoch 5/12
# 376/376 [==============================] - 1s 2ms/step - loss: 134.2405
# Epoch 6/12
# 376/376 [==============================] - 1s 2ms/step - loss: 134.2405
# Epoch 7/12
# 376/376 [==============================] - 1s 2ms/step - loss: 134.2405
# Epoch 8/12
# 376/376 [==============================] - 1s 2ms/step - loss: 134.2405
# Epoch 9/12
# 376/376 [==============================] - 1s 2ms/step - loss: 134.2405
# Epoch 10/12
# 376/376 [==============================] - 1s 2ms/step - loss: 134.2405
# Epoch 11/12
# 376/376 [==============================] - 1s 2ms/step - loss: 134.2405
# Epoch 12/12
# 376/376 [==============================] - 1s 2ms/step - loss: 134.2405

# %%
model.evaluate(x_test,y_test)
# Out:
# 94/94 [==============================] - 1s 2ms/step - loss: 133.9802
# 133.980224609375

# %%
pred = model.predict(x_test)

# %%
mean_absolute_error(y_test,pred)
# Out:
# 133.9802293882979
