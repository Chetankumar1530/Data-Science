# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans,DBSCAN,AgglomerativeClustering
from sklearn.preprocessing import MinMaxScaler,LabelEncoder,StandardScaler
import warnings
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering



warnings.filterwarnings("ignore")
sca = MinMaxScaler()
snd = StandardScaler()
ln = LabelEncoder()
#plt.style.use("seaborn-darkgrid")

# %%
data = pd.read_csv("crime_data.csv")

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Murder', 'Assault', 'UrbanPop', 'Rape'], dtype='object')

# %%
data.rename(columns={"Unnamed: 0": "macha"},inplace=True)

# %%
data.shape
# Out:
# (50, 5)

# %%
data.columns = ['city', 'Murder', 'Assault', 'UrbanPop', 'Rape']

# %%
data.shape
# Out:
# (50, 5)

# %%
data.isna().sum()
# Out:
# city        0
# Murder      0
# Assault     0
# UrbanPop    0
# Rape        0
# dtype: int64

# %%
data.dtypes
# Out:
# city         object
# Murder      float64
# Assault       int64
# UrbanPop      int64
# Rape        float64
# dtype: object

# %%
data.head()
# Out:
#          city  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
ddata = data.copy()

# %%
x = ddata.drop(labels="city",axis=1)

# %%
x.head(2)
# Out:
#    Murder  Assault  UrbanPop  Rape
# 0    13.2      236        58  21.2
# 1    10.0      263        48  44.5

# %%
model = KMeans(n_clusters=5)
model.fit(x)
pred = model.predict(x)
plt.scatter(x.Assault,x.Rape,c=pred,cmap=plt.cm.Accent)

# %%
for i in range(1,10):
    model = KMeans(n_clusters=i)
    model.fit(x)
    pred = model.predict(x)
    plt.scatter(x.Assault,x.UrbanPop,c=pred,cmap=plt.cm.Accent)
    plt.show()

# %% [markdown]
# ### DB Scan

# %%
model = DBSCAN(min_samples=4,eps=21)
pred = model.fit_predict(x)
plt.scatter(x.Assault,x.UrbanPop,c=pred)
pred

# %%
for i in range (1,10):    
    model = DBSCAN(min_samples=i,eps=i*0.24*21)
    pred = model.fit_predict(x)
    plt.scatter(x.Assault,x.UrbanPop,c=pred)
    plt.show()

# %% [markdown]
# ### Hierarchical Clustering

# %%
hc = AgglomerativeClustering(n_clusters=2)
pred  = hc.fit_predict(x)
plt.scatter(x.Assault,x.UrbanPop,c=pred)

# %%
for i in range (1,10):    
    hc = AgglomerativeClustering(n_clusters=i)
    pred  = hc.fit_predict(x)
    plt.scatter(x.Assault,x.UrbanPop,c=pred)
    plt.show()
