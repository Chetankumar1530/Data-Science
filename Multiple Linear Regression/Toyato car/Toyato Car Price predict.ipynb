# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
car = pd.read_csv("car toyato.csv")#,encoding="utf-8")

# %%
car = car[["Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]

# %%
car.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165
# 3  14950         26  48000  90  2000      3      5            210    1165
# 4  13750         30  38500  90  2000      3      5            210    1170

# %%
car.isna().sum()
# Out:
# Price            0
# Age_08_04        0
# KM               0
# HP               0
# cc               0
# Doors            0
# Gears            0
# Quarterly_Tax    0
# Weight           0
# dtype: int64

# %%
car.shape
# Out:
# (1436, 9)

# %%
a= car.columns
for i in range (0,9):
    sns.lmplot(x= a[i],y =  "Price" , data=car)
    plt.show()

# %%
car.head(2)
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165

# %%
x = car.drop(labels="Price", axis=1)
y = car[["Price"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=20)

# %%
from sklearn.linear_model import LinearRegression

# %%
lnr = LinearRegression()

# %%
# %%time
mod_1 = lnr.fit(x_train,y_train)
# Out:
# Wall time: 12.8 ms

# %%
y_pred = lnr.predict(x_test)

# %%
plt.scatter(y_test,y_pred)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,accuracy_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 1024.4928734264913

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 2076251.2884466085
