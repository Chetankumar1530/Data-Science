# %% [markdown]
# ### importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import statsmodels.formula.api as smf

# %%
cola_data = pd.read_excel('CocaCola_Sales_Rawdata.xlsx')
cola_data
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# 37   Q2_95  4936.000000
# 38   Q3_95  4895.000000
# 39   Q4_95  4333.000000
# 40   Q1_96  4194.000000
# 41   Q2_96  5253.000000

# %%
cola_data.isna().sum()
# Out:
# Quarter    0
# Sales      0
# dtype: int64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
seasonal_decompose(cola_data.Sales,period=12).plot()
plt.show()

# %%
cola_data['Quarter_ext'] = cola_data.Quarter.apply(lambda x : x.split('_')[0])
cola_data['Year'] = cola_data.Quarter.apply(lambda x : x.split('_')[1]).astype(int)

# %%
cola_data.head()
# Out:
#   Quarter        Sales Quarter_ext  Year
# 0   Q1_86  1734.827000          Q1    86
# 1   Q2_86  2244.960999          Q2    86
# 2   Q3_86  2533.804993          Q3    86
# 3   Q4_86  2154.962997          Q4    86
# 4   Q1_87  1547.818996          Q1    87

# %%
cola_data.Sales.plot()
plt.show()

# %%
sns.distplot(cola_data.Sales)
plt.show()

# %%
pd.plotting.lag_plot(cola_data.Sales)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(cola_data.Sales)
plt.show()

# %%
quarter_df = pd.get_dummies(cola_data.Quarter_ext)

# %%
df = pd.concat([cola_data,quarter_df],axis = 1)

# %%
df['t'] = np.arange(1,43)
df['t_square'] = df['t']*df['t']
df['log_sales'] = np.log(df.Sales)

# %%
df
# Out:
#    Quarter        Sales Quarter_ext  Year  Q1  Q2  Q3  Q4   t  t_square  \
# 0    Q1_86  1734.827000          Q1    86   1   0   0   0   1         1
# 1    Q2_86  2244.960999          Q2    86   0   1   0   0   2         4
# 2    Q3_86  2533.804993          Q3    86   0   0   1   0   3         9
# 3    Q4_86  2154.962997          Q4    86   0   0   0   1   4        16
# 4    Q1_87  1547.818996          Q1    87   1   0   0   0   5        25
# 5    Q2_87  2104.411995          Q2    87   0   1   0   0   6        36
# 6    Q3_87  2014.362999          Q3    87   0   0   1   0   7        49
# 7    Q4_87  1991.746998          Q4    87   0   0   0   1   8        64
# 8    Q1_88  1869.049999          Q1    88   1   0   0   0   9        81
# 9    Q2_88  2313.631996          Q2    88   0   1   0   0  10       100
# 10   Q3_88  2128.320000          Q3    88   0   0   1   0  11       121
# 11   Q4_88  2026.828999          Q4    88   0   0   0   1  12       144
# 12   Q1_89  1910.603996          Q1    89   1   0   0   0  13       169
# 13   Q2_89  2331.164993          Q2    89   0   1   0   0  14       196
# 14   Q3_89  2206.549995          Q3    89   0   0   1   0  15       225
# 15   Q4_89  2173.967995          Q4    89   0   0   0   1  16       256
# 16   Q1_90  2148.278000          Q1    90   1   0   0   0  17       289
# 17   Q2_90  2739.307999          Q2    90   0   1   0   0  18       324
# 18   Q3_90  2792.753998          Q3    90   0   0   1   0  19       361
# 19   Q4_90  2556.009995          Q4    90   0   0   0   1  20       400
# 20   Q1_91  2480.973999          Q1    91   1   0   0   0  21       441
# 21   Q2_91  3039.522995          Q2    91   0   1   0   0  22       484
# 22   Q3_91  3172.115997          Q3    91   0   0   1   0  23       529
# 23   Q4_91  2879.000999          Q4    91   0   0   0   1  24       576
# 24   Q1_92  2772.000000          Q1    92   1   0   0   0  25       625
# 25   Q2_92  3550.000000          Q2    92   0   1   0   0  26       676
# 26   Q3_92  3508.000000          Q3    92   0   0   1   0  27       729
# 27   Q4_92  3243.859993          Q4    92   0   0   0   1  28       784
# 28   Q1_93  3056.000000          Q1    93   1   0   0   0  29       841
# 29   Q2_93  3899.000000          Q2    93   0   1   0   0  30       900
# 30   Q3_93  3629.000000          Q3    93   0   0   1   0  31       961
# 31   Q4_93  3373.000000          Q4    93   0   0   0   1  32      1024
# 32   Q1_94  3352.000000          Q1    94   1   0   0   0  33      1089
# 33   Q2_94  4342.000000          Q2    94   0   1   0   0  34      1156
# 34   Q3_94  4461.000000          Q3    94   0   0   1   0  35      1225
# 35   Q4_94  4017.000000          Q4    94   0   0   0   1  36      1296
# 36   Q1_95  3854.000000          Q1    95   1   0   0   0  37      1369
# 37   Q2_95  4936.000000          Q2    95   0   1   0   0  38      1444
# 38   Q3_95  4895.000000          Q3    95   0   0   1   0  39      1521
# 39   Q4_95  4333.000000          Q4    95   0   0   0   1  40      1600
# 40   Q1_96  4194.000000          Q1    96   1   0   0   0  41      1681
# 41   Q2_96  5253.000000          Q2    96   0   1   0   0  42      1764
#
#     log_sales
# 0    7.458663
# 1    7.716443
# 2    7.837477
# 3    7.675529
# 4    7.344602
# 5    7.651791
# 6    7.608058
# 7    7.596767
# 8    7.533186
# 9    7.746574
# 10   7.663088
# 11   7.614228
# 12   7.555175
# 13   7.754123
# 14   7.699185
# 15   7.684309
# 16   7.672422
# 17   7.915461
# 18   7.934783
# 19   7.846203
# 20   7.816407
# 21   8.019456
# 22   8.062154
# 23   7.965199
# 24   7.927324
# 25   8.174703
# 26   8.162801
# 27   8.084519
# 28   8.024862
# 29   8.268475
# 30   8.196712
# 31   8.123558
# 32   8.117312
# 33   8.376090
# 34   8.403128
# 35   8.298291
# 36   8.256867
# 37   8.504311
# 38   8.495970
# 39   8.374015
# 40   8.341410
# 41   8.566555

# %% [markdown]
# ### Model Building | Model Training | Model Testing

# %%
#splitting data
train = df.head(38)
test = df.tail(4)

# %%
#Linear Model

linear_model = smf.ols('Sales~t',data = train).fit()
pred_linear = linear_model.predict(test['t'])
rmse_linear = np.sqrt(np.mean(((test.Sales)-(pred_linear))**2))
rmse_linear
# Out:
# 737.1568992951966

# %%
#Exponential

Exp = smf.ols('log_sales~t',data=train).fit()
pred_Exp = Exp.predict(test['t'])
rmse_Exp = np.sqrt(np.mean(((test['Sales'])-(np.exp(pred_Exp)))**2))
rmse_Exp
# Out:
# 586.8646090003343

# %%
#Quadratic 

Quad = smf.ols('Sales~t+t_square',data=train).fit()
pred_Quad = Quad.predict(test[["t","t_square"]])
rmse_Quad = np.sqrt(np.mean(((test['Sales'])-(pred_Quad))**2))
rmse_Quad
# Out:
# 445.8029895177929

# %%
#Additive seasonality 

add_sea = smf.ols('Sales~Q1+Q2+Q3+Q4',data=train).fit()
pred_add_sea = add_sea.predict(test[['Q1','Q2','Q3','Q4']])
rmse_add_sea = np.sqrt(np.mean(((test['Sales'])-(pred_add_sea))**2))
rmse_add_sea
# Out:
# 1931.3627904063205

# %%
#Additive Seasonality Quadratic 

add_sea_Quad = smf.ols('Sales~t+t_square+Q1+Q2+Q3+Q4',data=train).fit()
pred_add_sea_quad = add_sea_Quad.predict(test[['Q1','Q2','Q3','Q4','t','t_square']])
rmse_add_sea_quad = np.sqrt(np.mean(((test['Sales'])-(pred_add_sea_quad))**2))
rmse_add_sea_quad
# Out:
# 252.25576081760906

# %%
##Multiplicative Seasonality

Mul_sea = smf.ols('log_sales~Q1+Q2+Q3+Q4',data = train).fit()
pred_Mult_sea = Mul_sea.predict(test)
rmse_Mult_sea = np.sqrt(np.mean(((test['Sales'])-(np.exp(pred_Mult_sea)))**2))
rmse_Mult_sea
# Out:
# 2023.7328645103614

# %%
#Multiplicative Additive Seasonality 

Mul_Add_sea = smf.ols('log_sales~t+Q1+Q2+Q3+Q4',data = train).fit()
pred_Mult_add_sea = pd.Series(Mul_Add_sea.predict(test))
rmse_Mult_add_sea = np.sqrt(np.mean((np.array(test['Sales'])-np.array(np.exp(pred_Mult_add_sea)))**2))
rmse_Mult_add_sea
# Out:
# 290.2684788886582

# %%
# comparing
data = {"MODEL":pd.Series(["rmse_linear","rmse_Exp","rmse_Quad","rmse_add_sea","rmse_add_sea_quad","rmse_Mult_sea","rmse_Mult_add_sea"]),"RMSE_Values":pd.Series([rmse_linear,rmse_Exp,rmse_Quad,rmse_add_sea,rmse_add_sea_quad,rmse_Mult_sea,rmse_Mult_add_sea])}
table_rmse=pd.DataFrame(data)
table_rmse
# Out:
#                MODEL  RMSE_Values
# 0        rmse_linear   737.156899
# 1           rmse_Exp   586.864609
# 2          rmse_Quad   445.802990
# 3       rmse_add_sea  1931.362790
# 4  rmse_add_sea_quad   252.255761
# 5      rmse_Mult_sea  2023.732865
# 6  rmse_Mult_add_sea   290.268479

# %% [markdown]
# #### OBSERVATION
# * multiplicative additive seasonality gives the best prediction

# %% [markdown]
# ### Predict for new data

# %%
new_data = pd.DataFrame({'Quarter_ext':['Q3','Q4','Q1','Q2']})
new_data
# Out:
#   Quarter_ext
# 0          Q3
# 1          Q4
# 2          Q1
# 3          Q2

# %%
new_data['t'] = np.arange(43,47)

# %%
new_data
# Out:
#   Quarter_ext   t
# 0          Q3  43
# 1          Q4  44
# 2          Q1  45
# 3          Q2  46

# %%
new_df = pd.get_dummies(new_data.Quarter_ext)

# %%
for_pred = pd.concat([new_data,new_df],axis=1)

# %%
Mul_Add_sea = smf.ols('log_sales~t+Q1+Q2+Q3+Q4',data = df).fit()
pred_Mult_add_sea = pd.Series(Mul_Add_sea.predict(for_pred))

# %%
for_pred["predicted_sales"] = pd.Series(np.exp(pred_Mult_add_sea))
new_var = pd.concat([df,for_pred])
new_var
# Out:
#    Quarter        Sales Quarter_ext  Year  Q1  Q2  Q3  Q4   t  t_square  \
# 0    Q1_86  1734.827000          Q1  86.0   1   0   0   0   1       1.0
# 1    Q2_86  2244.960999          Q2  86.0   0   1   0   0   2       4.0
# 2    Q3_86  2533.804993          Q3  86.0   0   0   1   0   3       9.0
# 3    Q4_86  2154.962997          Q4  86.0   0   0   0   1   4      16.0
# 4    Q1_87  1547.818996          Q1  87.0   1   0   0   0   5      25.0
# 5    Q2_87  2104.411995          Q2  87.0   0   1   0   0   6      36.0
# 6    Q3_87  2014.362999          Q3  87.0   0   0   1   0   7      49.0
# 7    Q4_87  1991.746998          Q4  87.0   0   0   0   1   8      64.0
# 8    Q1_88  1869.049999          Q1  88.0   1   0   0   0   9      81.0
# 9    Q2_88  2313.631996          Q2  88.0   0   1   0   0  10     100.0
# 10   Q3_88  2128.320000          Q3  88.0   0   0   1   0  11     121.0
# 11   Q4_88  2026.828999          Q4  88.0   0   0   0   1  12     144.0
# 12   Q1_89  1910.603996          Q1  89.0   1   0   0   0  13     169.0
# 13   Q2_89  2331.164993          Q2  89.0   0   1   0   0  14     196.0
# 14   Q3_89  2206.549995          Q3  89.0   0   0   1   0  15     225.0
# 15   Q4_89  2173.967995          Q4  89.0   0   0   0   1  16     256.0
# 16   Q1_90  2148.278000          Q1  90.0   1   0   0   0  17     289.0
# 17   Q2_90  2739.307999          Q2  90.0   0   1   0   0  18     324.0
# 18   Q3_90  2792.753998          Q3  90.0   0   0   1   0  19     361.0
# 19   Q4_90  2556.009995          Q4  90.0   0   0   0   1  20     400.0
# 20   Q1_91  2480.973999          Q1  91.0   1   0   0   0  21     441.0
# 21   Q2_91  3039.522995          Q2  91.0   0   1   0   0  22     484.0
# 22   Q3_91  3172.115997          Q3  91.0   0   0   1   0  23     529.0
# 23   Q4_91  2879.000999          Q4  91.0   0   0   0   1  24     576.0
# 24   Q1_92  2772.000000          Q1  92.0   1   0   0   0  25     625.0
# 25   Q2_92  3550.000000          Q2  92.0   0   1   0   0  26     676.0
# 26   Q3_92  3508.000000          Q3  92.0   0   0   1   0  27     729.0
# 27   Q4_92  3243.859993          Q4  92.0   0   0   0   1  28     784.0
# 28   Q1_93  3056.000000          Q1  93.0   1   0   0   0  29     841.0
# 29   Q2_93  3899.000000          Q2  93.0   0   1   0   0  30     900.0
# 30   Q3_93  3629.000000          Q3  93.0   0   0   1   0  31     961.0
# 31   Q4_93  3373.000000          Q4  93.0   0   0   0   1  32    1024.0
# 32   Q1_94  3352.000000          Q1  94.0   1   0   0   0  33    1089.0
# 33   Q2_94  4342.000000          Q2  94.0   0   1   0   0  34    1156.0
# 34   Q3_94  4461.000000          Q3  94.0   0   0   1   0  35    1225.0
# 35   Q4_94  4017.000000          Q4  94.0   0   0   0   1  36    1296.0
# 36   Q1_95  3854.000000          Q1  95.0   1   0   0   0  37    1369.0
# 37   Q2_95  4936.000000          Q2  95.0   0   1   0   0  38    1444.0
# 38   Q3_95  4895.000000          Q3  95.0   0   0   1   0  39    1521.0
# 39   Q4_95  4333.000000          Q4  95.0   0   0   0   1  40    1600.0
# 40   Q1_96  4194.000000          Q1  96.0   1   0   0   0  41    1681.0
# 41   Q2_96  5253.000000          Q2  96.0   0   1   0   0  42    1764.0
# 0      NaN          NaN          Q3   NaN   0   0   1   0  43       NaN
# 1      NaN          NaN          Q4   NaN   0   0   0   1  44       NaN
# 2      NaN          NaN          Q1   NaN   1   0   0   0  45       NaN
# 3      NaN          NaN          Q2   NaN   0   1   0   0  46       NaN
#
#     log_sales  predicted_sales
# 0    7.458663              NaN
# 1    7.716443              NaN
# 2    7.837477              NaN
# 3    7.675529              NaN
# 4    7.344602              NaN
# 5    7.651791              NaN
# 6    7.608058              NaN
# 7    7.596767              NaN
# 8    7.533186              NaN
# 9    7.746574              NaN
# 10   7.663088              NaN
# 11   7.614228              NaN
# 12   7.555175              NaN
# 13   7.754123              NaN
# 14   7.699185              NaN
# 15   7.684309              NaN
# 16   7.672422              NaN
# 17   7.915461              NaN
# 18   7.934783              NaN
# 19   7.846203              NaN
# 20   7.816407              NaN
# 21   8.019456              NaN
# 22   8.062154              NaN
# 23   7.965199              NaN
# 24   7.927324              NaN
# 25   8.174703              NaN
# 26   8.162801              NaN
# 27   8.084519              NaN
# 28   8.024862              NaN
# 29   8.268475              NaN
# 30   8.196712              NaN
# 31   8.123558              NaN
# 32   8.117312              NaN
# 33   8.376090              NaN
# 34   8.403128              NaN
# 35   8.298291              NaN
# 36   8.256867              NaN
# 37   8.504311              NaN
# 38   8.495970              NaN
# 39   8.374015              NaN
# 40   8.341410              NaN
# 41   8.566555              NaN
# 0         NaN      5105.188052
# 1         NaN      4712.333489
# 2         NaN      4458.542939
# 3         NaN      5670.883819

# %%
new_var[['Sales','predicted_sales']].reset_index(drop=True).plot()
plt.show()
